# %% [markdown]
# ## 1. Funciones i gràfiques
# ### 1.1 Definir  funcions

# %% [markdown]
# #### Exemple 1.1

# %%
f(x)=cos(pi*x)+3

# %%
show(f)
# Out:
# x |--> cos(pi*x) + 3

# %%
f(1/2)
# Out:
# 3

# %%
f(1/3)
# Out:
# 7/2

# %%
f(0.5)
# Out:
# cos(0.500000000000000*pi) + 3

# %%
f(0.5).n()
# Out:
# 3.00000000000000

# %% [markdown]
# #### Exemple 1.2

# %%
g(t)=2*t^2-1

# %%
show(g)
# Out:
# t |--> 2*t^2 - 1

# %%
g(x)
# Out:
# 2*x^2 - 1

# %%
g(2)
# Out:
# 7

# %%
g(1.345)
# Out:
# 2.61805000000000

# %%
v=3.01

# %%
g(v)
# Out:
# 17.1202000000000

# %% [markdown]
# #### Exemple 1.3

# %%
v=5

# %%
u
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5f8475445b2f> in <module>
# ----> 1 u
#
# NameError: name 'u' is not defined

# %%
v
# Out:
# 5

# %%
F(u,v)=u*v

# %%
u
# Out:
# u

# %%
v
# Out:
# v

# %% [markdown]
# #### Exemple 1.4

# %%
g(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-f7759e74e2df> in <module>
# ----> 1 g(y)
#
# NameError: name 'y' is not defined

# %%
var('y')
# Out:
# y

# %%
g(y)
# Out:
# 2*y^2 - 1

# %% [markdown]
# #### Exemple 1.5

# %%
h(x,y)=x^2-x*y+ln(x^2+y^2)

# %%
show(h)
# Out:
# (x, y) |--> x^2 - x*y + log(x^2 + y^2)

# %%
h(2,3)
# Out:
# log(13) - 2

# %%
h(1,x)
# Out:
# -x + log(x^2 + 1) + 1

# %% [markdown]
# ### 1.2 Gràfic d'una funció

# %% [markdown]
# #### Exemple 1.6

# %%
plot(3*x^2-8,x,-5,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
(3*x^2-8).plot(x,-5,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
(3*x^2-8).plot(-5,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(g)
# Out:
# t |--> 2*t^2 - 1

# %%
plot(g,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## 2 Límits
# ### 2.1 Asímptotes verticals
# #### Exemple 2.1

# %%
f(x)=x/(x-2)

# %%
f.plot(x,-5,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f.plot(x,-5,5,ymin=-15, ymax=15)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f.plot(x,-5,5,ymin=-15,ymax=15,detect_poles=true)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f.plot(x,-5,5,ymin=-15,ymax=15,detect_poles='show')
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# ### 2.2 Límit d'una expressió
# #### Exemple 2.2

# %%
limit(sin(x)/x,x=0)
# Out:
# 1

# %%
lim((x-sin(x))/x^3,x=0)
# Out:
# 1/6

# %%
lim((1-cos(x))/x^2,x=0)
# Out:
# 1/2

# %%
lim((x^3+3*x^2-x-3)/(x-1),x=1)
# Out:
# 8

# %%
limit(e^(-1/x^2)/x^5,x=0)
# Out:
# 0

# %% [markdown]
# #### Exemple 2.3

# %%
f(x)=x/(x-2)

# %%
plot(f,-5,5,ymin=-15,ymax=15,detect_poles='show')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
limit(f,x=2)
# Out:
# x |--> Infinity

# %%
limit(f,x=2,dir='-')
# Out:
# x |--> -Infinity

# %%
limit(f,x=2,dir='+')
# Out:
# x |--> +Infinity

# %% [markdown]
# ### 2.3 Asímptotes horitzontals
# #### Exemple 2.4

# %%
limit(x/(x+2), x=infinity)
# Out:
# 1

# %%
limit(x*(sqrt(x+1)-sqrt(x-1))/sqrt(x), x=infinity)
# Out:
# 1

# %%
limit((sqrt(x+1)-sqrt(x)+1)^sqrt(x),x=oo)
# Out:
# e^(1/2)

# %%
limit((x^3-8*x+7)/(200*x+1024),x=oo)
# Out:
# +Infinity

# %%
limit(e^x,x=oo)
# Out:
# +Infinity

# %%
limit(e^x,x=-oo)
# Out:
# 0

# %% [markdown]
# #### Exemple 2.5

# %%
plot([1-x^2/2,cos(x)],-pi/2,pi/2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(1-x^2/2, -pi/2,pi/2,color='red') + plot(cos(x), -pi/2, pi/2, color='green')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
dibparabola=plot(1-x^2/2,-pi/2,pi/2,color='red', legend_label="$1-x^2$")

# %%
dibcosinus=plot(cos(x),-pi/2,pi/2,color='green', legend_label="$\cos(x)$")

# %%
dibparabola+dibcosinus
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sorted(colors)
# Out:
# ['aliceblue',
#  'antiquewhite',
#  'aqua',
#  'aquamarine',
#  'automatic',
#  'azure',
#  'beige',
#  'bisque',
#  'black',
#  'blanchedalmond',
#  'blue',
#  'blueviolet',
#  'brown',
#  'burlywood',
#  'cadetblue',
#  'chartreuse',
#  'chocolate',
#  'coral',
#  'cornflowerblue',
#  'cornsilk',
#  'crimson',
#  'cyan',
#  'darkblue',
#  'darkcyan',
#  'darkgoldenrod',
#  'darkgray',
#  'darkgreen',
#  'darkgrey',
#  'darkkhaki',
#  'darkmagenta',
#  'darkolivegreen',
#  'darkorange',
#  'darkorchid',
#  'darkred',
#  'darksalmon',
#  'darkseagreen',
#  'darkslateblue',
#  'darkslategray',
#  'darkslategrey',
#  'darkturquoise',
#  'darkviolet',
#  'deeppink',
#  'deepskyblue',
#  'dimgray',
#  'dimgrey',
#  'dodgerblue',
#  'firebrick',
#  'floralwhite',
#  'forestgreen',
#  'fuchsia',
#  'gainsboro',
#  'ghostwhite',
#  'gold',
#  'goldenrod',
#  'gray',
#  'green',
#  'greenyellow',
#  'grey',
#  'honeydew',
#  'hotpink',
#  'indianred',
#  'indigo',
#  'ivory',
#  'khaki',
# ...

# %%
plot?

# %% [markdown]
# #### Exercici 2.1

# %%
f(x)=x/(x-2);g(x)=1

# %%
dibf=plot(f,x,-5,5,ymin=-15, ymax=15,color='red',legend_label="$\f(x)$",detect_poles="show")

# %%
dibg=plot(g,x,-5,5,ymin=-15, ymax=15,color='grey', legend_label="$\g(x)$", linestyle="dashed")

# %%
dibf+dibg
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ### 2.4 Escales dels eixos
# #### Exemple 2.6

# %%
plot(sqrt(1-x^2),x,-1,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sqrt(1-x^2),x,-1,1,aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sqrt(1-x^2),x,-1,1,aspect_ratio=2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sqrt(1-x^2),x,-1,1,aspect_ratio=1/2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# #### Exercici 2.2

# %%
plot(sin(x),x,0,4*pi,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# #### Exercici 2.3

# %%
plot(3*x^4-6*x^2, x, -5, 5, ymin=-4, ymax=4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Llavors, la funció talla l'eix de les abcisses aproximadament en -1'5, 0 i 1'5

# %% [markdown]
# ### 2.5 Derivades
# #### Exemple 2.7

# %%
diff(x^3-2*x^2+4*x-5,x)
# Out:
# 3*x^2 - 4*x + 4

# %%
(x^3-2*x^2+4*x-5).diff()
# Out:
# 3*x^2 - 4*x + 4

# %% [markdown]
# #### Exemple 2.8

# %%
var('a')
# Out:
# a

# %%
f(x)=tan(a*x^2)

# %%
f
# Out:
# x |--> tan(a*x^2)

# %%
df=f.diff()

# %%
show(df)
# Out:
# x |--> (2*(tan(a*x^2)^2 + 1)*a*x)

# %%
ddf=diff(df)

# %%
show(ddf)
# Out:
# [x |--> 8*(tan(a*x^2)^2 + 1)*a^2*x^2*tan(a*x^2) + 2*(tan(a*x^2)^2 + 1)*a]

# %%
diff(f(x),x) #Primera derivada
# Out:
# 2*(tan(a*x^2)^2 + 1)*a*x

# %%
diff(f(x),x,x) #Segona derivada
# Out:
# 8*(tan(a*x^2)^2 + 1)*a^2*x^2*tan(a*x^2) + 2*(tan(a*x^2)^2 + 1)*a

# %%
diff(f(x),x,x,x) #Tercera derivada
# Out:
# 32*(tan(a*x^2)^2 + 1)*a^3*x^3*tan(a*x^2)^2 + 16*(tan(a*x^2)^2 + 1)^2*a^3*x^3 + 24*(tan(a*x^2)^2 + 1)*a^2*x*tan(a*x^2)

# %%
diff(f(x),x,2)
# Out:
# 8*(tan(a*x^2)^2 + 1)*a^2*x^2*tan(a*x^2) + 2*(tan(a*x^2)^2 + 1)*a

# %%
diff(f(x),x,3)
# Out:
# 32*(tan(a*x^2)^2 + 1)*a^3*x^3*tan(a*x^2)^2 + 16*(tan(a*x^2)^2 + 1)^2*a^3*x^3 + 24*(tan(a*x^2)^2 + 1)*a^2*x*tan(a*x^2)

# %%
diff(f(x),x,12)
# Out:
# 8388608*(tan(a*x^2)^2 + 1)*a^12*x^12*tan(a*x^2)^11 + 8539602944*(tan(a*x^2)^2 + 1)^2*a^12*x^12*tan(a*x^2)^9 + 231508803584*(tan(a*x^2)^2 + 1)^3*a^12*x^12*tan(a*x^2)^7 + 910944108544*(tan(a*x^2)^2 + 1)^4*a^12*x^12*tan(a*x^2)^5 + 719369273344*(tan(a*x^2)^2 + 1)^5*a^12*x^12*tan(a*x^2)^3 + 138412032*(tan(a*x^2)^2 + 1)*a^11*x^10*tan(a*x^2)^10 + 91620376576*(tan(a*x^2)^2 + 1)^6*a^12*x^12*tan(a*x^2) + 70105694208*(tan(a*x^2)^2 + 1)^2*a^11*x^10*tan(a*x^2)^8 + 1179824160768*(tan(a*x^2)^2 + 1)^3*a^11*x^10*tan(a*x^2)^6 + 2872776327168*(tan(a*x^2)^2 + 1)^4*a^11*x^10*tan(a*x^2)^4 + 1224808071168*(tan(a*x^2)^2 + 1)^5*a^11*x^10*tan(a*x^2)^2 + 778567680*(tan(a*x^2)^2 + 1)*a^10*x^8*tan(a*x^2)^9 + 47821357056*(tan(a*x^2)^2 + 1)^6*a^11*x^10 + 195420487680*(tan(a*x^2)^2 + 1)^2*a^10*x^8*tan(a*x^2)^7 + 1984179732480*(tan(a*x^2)^2 + 1)^3*a^10*x^8*tan(a*x^2)^5 + 2799729377280*(tan(a*x^2)^2 + 1)^4*a^10*x^8*tan(a*x^2)^3 + 537990266880*(tan(a*x^2)^2 + 1)^5*a^10*x^8*tan(a*x^2) + 1816657920*(tan(a*x^2)^2 + 1)*a^
# ...

# %% [markdown]
# #### Exemple 2.10

# %%
g(x,y)=y*exp(2*x^2+x-1)

# %%
dg_x=diff(g(x,y),x); show(dg_x)
# Out:
# (4*x + 1)*y*e^(2*x^2 + x - 1)

# %%
dg_y=diff(g(x,y),y); show(dg_y)
# Out:
# e^(2*x^2 + x - 1)

# %%
dg_xx=diff(g(x,y),x,x); show(dg_xx)
# Out:
# (4*x + 1)^2*y*e^(2*x^2 + x - 1) + 4*y*e^(2*x^2 + x - 1)

# %%
dg_yy=diff(g(x,y),y,y); show(dg_yy)
# Out:
# 0

# %%
dg_xy=diff(g(x,y),x,y); show(dg_xy)
# Out:
# (4*x + 1)*e^(2*x^2 + x - 1)

# %%
dg_yx=diff(g(x,y),y,x); show(dg_yx)
# Out:
# (4*x + 1)*e^(2*x^2 + x - 1)

# %% [markdown]
# #### Exercici 2.4

# %%
h(x)=20/(x^2+4)

# %%
dh=diff(h(x),x); show(dh)
# Out:
# -40*x/(x^2 + 4)^2

# %%
ddh=diff(h(x),x,2); show(ddh)
# Out:
# 160*x^2/(x^2 + 4)^3 - 40/(x^2 + 4)^2

# %% [markdown]
# #### Exercici 2.5

# %%
h(x,y)=(x*exp(x*y)*sin(y^2))/(log(x^2+y^2+2)); show(h)
# Out:
# (x, y) |--> x*e^(x*y)*sin(y^2)/log(x^2 + y^2 + 2)

# %% [markdown]
# (a)

# %%
dh_x(x,y)=diff(h(x,y),x); show(dh_x)
# Out:
# (x, y) |--> x*y*e^(x*y)*sin(y^2)/log(x^2 + y^2 + 2) - 2*x^2*e^(x*y)*sin(y^2)/((x^2 + y^2 + 2)*log(x^2 + y^2 + 2)^2) + e^(x*y)*sin(y^2)/log(x^2 + y^2 + 2)

# %% [markdown]
# (b)

# %%
dh_y=diff(h(x,y),y); show(dh_y)
# Out:
# 2*x*y*cos(y^2)*e^(x*y)/log(x^2 + y^2 + 2) + x^2*e^(x*y)*sin(y^2)/log(x^2 + y^2 + 2) - 2*x*y*e^(x*y)*sin(y^2)/((x^2 + y^2 + 2)*log(x^2 + y^2 + 2)^2)

# %% [markdown]
# (c)

# %%
dh_x(1,1/2)
# Out:
# 3/2*e^(1/2)*sin(1/4)/log(13/4) - 8/13*e^(1/2)*sin(1/4)/log(13/4)^2

# %%
dh_x(1,0.5)
# Out:
# 0.338421775375366

# %%
show(diff(h(x,y),x,2))
# Out:
# x*y^2*e^(x*y)*sin(y^2)/log(x^2 + y^2 + 2) - 4*x^2*y*e^(x*y)*sin(y^2)/((x^2 + y^2 + 2)*log(x^2 + y^2 + 2)^2) + 2*y*e^(x*y)*sin(y^2)/log(x^2 + y^2 + 2) + 4*x^3*e^(x*y)*sin(y^2)/((x^2 + y^2 + 2)^2*log(x^2 + y^2 + 2)^2) + 8*x^3*e^(x*y)*sin(y^2)/((x^2 + y^2 + 2)^2*log(x^2 + y^2 + 2)^3) - 6*x*e^(x*y)*sin(y^2)/((x^2 + y^2 + 2)*log(x^2 + y^2 + 2)^2)

# %% [markdown]
# ### 2.6 Rectes tangents
# #### Exemple 2.11

# %%
f(x)=exp(x)-x

# %%
plot(f(x),-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
diff(f(x))
# Out:
# e^x - 1

# %%
tg1(x)=f(1)+diff(f)(1)*(x-1); show(tg1)
# Out:
# x |--> (x - 1)*(e - 1) + e - 1

# %%
plot(f(x),-1,2)+plot(tg1(x),1/2,3/2,color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# #### Exercici 2.6

# %%
h(x)=(x-exp(1-x^2))/(x-2)

# %%
plot(h(x),x,-4,8, ymin=-20,ymax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
limit(h(x),x=2, dir='-')
# Out:
# -Infinity

# %%
limit(h(x),x=2, dir='+')
# Out:
# +Infinity

# %% [markdown]
# Assimptota vertical en x=2

# %%
limit(h(x),x=+oo)
# Out:
# 1

# %%
limit(h(x),x=-oo)
# Out:
# 1

# %%
y(x)=1

# %% [markdown]
# Assimptota horitzontal en y=1

# %%
tg_minus1(x)=h(-1)+diff(h)(-1)*(x+1)

# %%
plot(h(x),-4,8,ymin=-20, ymax=20,color='blue',detect_poles="show")+plot(y(x),-4,8,color='violet',linestyle="dashed")+plot(tg_minus1(x),-4,8,color='red',linestyle="dashed")
# Out:
# Graphics object consisting of 5 graphics primitives
