# %% [markdown]
# # Pràctica 4. Funcions
# ## 1. Zeros de funcions
# ### 1.1 Solucions formals (la instrucció <code> solve </code> )
# #### Exemple 1.1

# %%
eq=3*x^3-4*x^2-43*x+84==0

# %%
ss=solve(eq,x)

# %%
show(ss)
# Out:
# [x == 3, x == (7/3), x == -4]

# %%
show(x.subs(ss[1]))
# Out:
# 7/3

# %%
show(n(x.subs(ss[1])))
# Out:
# 2.33333333333333

# %%
[x.subs(sol) for sol in ss]
# Out:
# [3, 7/3, -4]

# %%
[n(x.subs(sol)) for sol in ss]
# Out:
# [3.00000000000000, 2.33333333333333, -4.00000000000000]

# %%
[eq.subs(sol) for sol in ss]
# Out:
# [0 == 0, 0 == 0, 0 == 0]

# %%
[bool(eq.subs(sol)) for sol in ss]
# Out:
# [True, True, True]

# %% [markdown]
# #### Exercici 1.1
# ##### (a)

# %%
eq1=x^3-5*x^2-29*x+105==0

# %%
show(solve(eq1,x))
# Out:
# [x == 7, x == 3, x == -5]

# %% [markdown]
# ##### (b)

# %%
eq2=(2*x)/(4*x^2-3)==5

# %%
show(solve(eq2,x))
# Out:
# [x == -1/20*sqrt(301) + 1/20, x == 1/20*sqrt(301) + 1/20]

# %% [markdown]
# #### Exemple 1.2

# %%
show(solve(5*e^(x/4)==43,x))
# Out:
# [x == 4*log(43/5)]

# %% [markdown]
# #### Exemple 1.3

# %%
show(solve(sin(x)==1/2,x))
# Out:
# [x == 1/6*pi]

# %% [markdown]
# #### Exemple 1.4

# %%
solve(sin(x)==1/2,x,to_poly_solve='force')
# Out:
# [x == 5/6*pi + 2*pi*z1752, x == 1/6*pi + 2*pi*z1798]

# %%
show(_)
# Out:
# [x == 5/6*pi + 2*pi*z1752, x == 1/6*pi + 2*pi*z1798]

# %% [markdown]
# #### Exercici 1.2
# ##### (a)

# %%
show(solve(3-abs(x^2-1)==0,x))
# Out:
# [abs(x^2 - 1) == 3]

# %% [markdown]
# ##### (b)

# %%
show(solve(2^x==32,x))
# Out:
# [x == 5]

# %% [markdown]
# ##### (c)

# %%
solve(e^(x)^2==1-x^2,x)
# Out:
# [x == -sqrt(-e^(x^2) + 1), x == sqrt(-e^(x^2) + 1)]

# %%
show(_)
# Out:
# [x == -sqrt(-e^(x^2) + 1), x == sqrt(-e^(x^2) + 1)]

# %% [markdown]
# #### Exercici 1.3
# ##### (a)

# %%
s1=solve(2*cos(x)+1==0, x, to_poly_solve='force')

# %%
var('z')
# Out:
# z

# %%
show(s1)
# Out:
# [x == 2/3*pi + 2*pi*z3464, x == -2/3*pi + 2*pi*z3510]

# %%
solve([2/3*pi+2*pi*z>=-7*pi,2/3*pi+2*pi*z<=11*pi],z)
# Out:
# [[(-23/6) < z, z < (31/6)], [z == (-23/6)], [z == (31/6)]]

# %%
solve([-2/3*pi+2*pi*z>=-7*pi,-2/3*pi+2*pi*z<=11*pi],z)
# Out:
# [[(-19/6) < z, z < (35/6)], [z == (-19/6)], [z == (35/6)]]

# %% [markdown]
# Com que z té que ser enter tenim que les solució de de 2·cos(x)+1==0 que són 2/3π+2πz per -3<=z<=5 i -2/3π+2πz per -3<=z<=5

# %% [markdown]
# ##### (b)

# %%
s2=solve((sin(2*x))^2-1==0,x); show(s2)
# Out:
# [x == -1/4*pi, x == 1/4*pi]

# %% [markdown]
# ### 1.2 Solucions numèriques/arpoximades (la instrucció <code> find_root </code>
# #### Exemple 1.5

# %%
eq2=x^5-2*x^3-17*x^2-6*x+2==0

# %%
solve(eq2,x)
# Out:
# [0 == x^5 - 2*x^3 - 17*x^2 - 6*x + 2]

# %%
solve(eq2,x,to_poly_solve=True)
# Out:
# [x == -0.5869325346784363,
#  x == 0.2079177057356608,
#  x == 2.910146390711762,
#  x == (-1.265565727097873 - 2.007484031928358*I),
#  x == (-1.265565727097873 + 2.007484031928358*I)]

# %% [markdown]
# #### Exemple 1.6

# %%
eq3=x^3+1==e^x

# %%
solve(eq3,x)
# Out:
# [x == 1/2*(I*sqrt(3) - 1)*(e^x - 1)^(1/3), x == -1/2*(I*sqrt(3) + 1)*(e^x - 1)^(1/3), x == (e^x - 1)^(1/3)]

# %%
solve(eq3,x,to_poly_solve=True)
# Out:
# []

# %%
plot([x^3+1,exp(x)])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot([x^3+1,exp(x)],-5,5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# #### Exemple 1.7

# %%
eq3.find_root(-0.5,0.5)
# Out:
# -2.43999028074386e-17

# %%
domini1=(-2,2)
domini2=(4,5)

# %%
plot([x^3+1,exp(x)],domini1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot([x^3+1,exp(x)],domini2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
s1=find_root(eq3,-1,-0.5)
s2=find_root(eq3,-0.5,0.5)
s3=find_root(eq3,1,2)
s4=find_root(eq3,4.4,4.8)

# %%
show([s1,s2,s3,s4])
# Out:
# [-0.8251554696886889,
#  -2.43999028074386e-17,
#  1.5450072790732132,
#  4.567036836946052]

# %% [markdown]
# #### Exercici 1.4

# %%
eq=x^5-4*x^3+3*x^2+7*x-1==0

# %%
solve(eq,x, to_poly_solve='force')
# Out:
# [x == -1.848049551924091,
#  x == -1.293392673741869,
#  x == 0.1363327096444974,
#  x == (1.502554749590459 - 0.9005775488292209*I),
#  x == (1.502554749590459 + 0.9005775488292209*I)]

# %%
plot([eq],-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
s1=find_root(eq,-2,-1.5)
s2=find_root(eq,-1.5,-1)
s3=find_root(eq,0,0.5)

# %%
show([s1,s2,s3])
# Out:
# [-1.8480495403782895, -1.293392663436565, 0.13633270463395813]

# %% [markdown]
# ### 1.3 Representació gràfica de les solucions
# #### Exemple 1.8

# %%
eq4=x^2/20-10*x==15*cos(x+15)

# %%
plot(eq4.lhs(),-10,10, color='red')+plot(eq4.rhs(),-10,10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
eq4.find_root(1,2)
# Out:
# 1.27409207502708

# %%
plot(eq4.lhs(),150,205, color='red')+plot(eq4.rhs(),150,205)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(eq4.lhs(),195,205, color='red')+plot(eq4.rhs(),195,205)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
eq4.find_root(200,200.5)
# Out:
# 200.11937891579402

# %% [markdown]
# #### Exemple 1.9

# %%
point((1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
point([(0,2),(-1,-3),(3,1.5)],xmin=-1.5,xmax=3.5,ymin=-3.5,ymax=2.5, color='red', marker="s",size=25, aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# #### Exemple 1.10

# %%
ll1=plot(-3*x+5,-3,5,color='green'); ll1
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
ll2=plot(9-x^2,-3,5,color='red');ll2
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p1=point([(-1,8),(4,-7)], color='blue', marker="*", size=100)

# %%
(p1+ll1+ll2).show(xmin=-15,xmax=15, aspect_ratio=1)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# #### Exercici 1.5

# %%
g=plot([x^2+x-6],-5,5 ,color='blue'); g
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p=point([(-3,0),(0,-6),(2,0)],color='red', marker="s", size=50)

# %%
(p+g).show(xmin=-5,xmax=5,ymin=-10, ymax=5 )
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# #### Exemple 1.11

# %%
x0=eq4.find_root(1,2)

# %%
y0=eq4.lhs().subs(x=x0)

# %%
p0=(x0,y0)

# %%
plot(eq4.lhs(),-10,10,color='red')+plot(eq4.rhs(),-10,10)+point(p0,color='green', marker="*", size=80, legend_label=(p0))
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# #### Exercici 1.6

# %%
x1=eq4.find_root(200,200.5)

# %%
y1=eq4.rhs().subs(x=x1)

# %%
p1=(x1,y1)

# %%
plot(eq4.lhs(),-10,210,color='red',legend_label=(eq4.lhs())+plot(eq4.rhs(),-10,210)+point([p0,p1],color='violet', marker="o", size=150, markeredgecolor="black", legend_label=(p0,p1))
# Out:
#   File "<ipython-input-14-333d671b5ae4>", line 1
#     plot(eq4.lhs(),-Integer(10),Integer(210),color='red',legend_label=(eq4.lhs())+plot(eq4.rhs(),-Integer(10),Integer(210))+point([p0,p1],color='violet', marker="o", size=Integer(150), markeredgecolor="black", legend_label=(p0,p1))
#                                                                                                                                                                                                                                        ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# #### Exemple 1.12

# %%
line([(0,2),(-1,-3),(3,1.5)],
     xmin=-1.5,xmax=3.5,ymin=-3.5,ymax=2.5,
     color='red',aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# #### Exercici 1.7

# %%
eq=x^2==cosh(x)-1

# %%
x0=eq.find_root(-4,-2); y0=eq.lhs().subs(x=x0); p0=(x0,y0)

# %%
x1=eq.find_root(-1,1); x1
# Out:
# -4.933333194555457e-09

# %% [markdown]
# Com que es aproximadamente zero prenem x1=0

# %%
x1=0; y1=eq.lhs().subs(x=x1); p1=(x1,y1)

# %%
x2=eq.find_root(2,4); y2=eq.lhs().subs(x=x2); p2=(x2,y2)

# %%
plot(eq.lhs(),-6,6, ymax=14,color='blue',legend_label=eq.lhs())+plot(eq.rhs(), -6,6,ymax=14,color='green', legend_label=eq.rhs())+point(p0,color='orange', marker="o", size=45, legend_label=p0)+point(p1,color='violet', marker="o", size=45, legend_label=p1)+point(p2,color='red', marker="o", size=45, legend_label=p2)
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# ## 2 Màxims i mínims de funcions
# #### Exemple 2.1

# %%
f=x^3-2*x^2+3*x-7

# %%
df=f.diff()

# %%
eq= df==0

# %%
sols=solve(eq,x)

# %%
show(sols)
# Out:
# [x == -1/3*I*sqrt(5) + 2/3, x == 1/3*I*sqrt(5) + 2/3]

# %%
[x.subs(k) for k in sols]
# Out:
# [-1/3*I*sqrt(5) + 2/3, 1/3*I*sqrt(5) + 2/3]

# %%
[x.subs(k).n() for k in sols]
# Out:
# [0.666666666666667 - 0.745355992499930*I,
#  0.666666666666667 + 0.745355992499930*I]

# %%
[f.subs(k).expand() for k in sols]
# Out:
# [-10/27*I*sqrt(5) - 151/27, 10/27*I*sqrt(5) - 151/27]

# %%
[f.subs(k).n() for k in sols]
# Out:
# [-5.59259259259259 - 0.828173324999922*I,
#  -5.59259259259259 + 0.828173324999922*I]

# %% [markdown]
# #### Exercici 2.1

# %% [markdown]
# ## 3 Integrals
# #### Exemple 3.1

# %%
f(x)=x*sin(x)

# %%
var('a','b')
# Out:
# (a, b)

# %%
integral(f(x),x,a,b)
# Out:
# a*cos(a) - b*cos(b) - sin(a) + sin(b)

# %% [markdown]
# #### Exemple 3.2

# %%
integral(f(x),x,0,3)
# Out:
# -3*cos(3) + sin(3)

# %%
integral(f(x),x,0,3).n()
# Out:
# 3.11109749786120

# %%
integral(f(x),x,1.,2.)
# Out:
# 1.44042242098021

# %%
integral(e^(-x^2), x,-infinity,infinity)
# Out:
# sqrt(pi)

# %% [markdown]
# #### Exemple 3.3

# %%
integral(sin(x),x)
# Out:
# -cos(x)

# %%
h(x)=integral(sin(x),x)

# %%
diff(h(x),x)
# Out:
# sin(x)

# %% [markdown]
# #### Exemple 3.4

# %%
h(0)
# Out:
# -1

# %%
F(x)=h(x)-h(0);show(F)
# Out:
# x |--> -cos(x) + 1

# %% [markdown]
# ### 3.1 Representar integrals com àrees
# #### Exemple 3.5

# %%
g(x)=x*sin(x)

# %%
plot(g(x),(x,0,4))+plot(g(x),(x,1,2), fill='axis')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
integral(g(x), x, 1,2).n()
# Out:
# 1.44042242098021

# %%
plot(sin(x)/x,(x,-50,50), fill='axis')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
integral(sin(x)/x, x,-50,50).n()
# Out:
# 6.24482679856167

# %% [markdown]
# #### Exercici 3.1

# %%
integral(abs(sin(x)/x), x,-50,50).n()
# Out:
# 7.21222311604634

# %%
plot(eq.lhs(),6,-6, color='blue')+plot(eq.rhs(), 6,-6,color='green')
# Out:
# Graphics object consisting of 0 graphics primitives
